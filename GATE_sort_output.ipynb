# %%
import os, glob, csv, codecs
import shutil
import re

# %%
Column_list =\
['1Run ID', '1Event ID', '1Source ID',\
 '1Source Position X', '1Source Position Y',\
 '1Source Position Z', '1Time stamp', '1Deposited energy',\
 '1world referential Position X',\
 '1world referential Position Y',\
 '1world referential Position Z', '1Volume ID1(8-bytes, G4double)', '1Volume ID2(8-bytes, G4double)',\
 '1Volume ID3(8-bytes, G4double)', '1Volume ID4(4-bytes, G4int)', '1Volume ID5(4-bytes, G4int)', '1Volume ID6(4-bytes, G4int)', \
 '1Number of Compton interactions in phantoms before reaching the detector',\
 '1Number of Compton interactions in detectors before reaching the detector',\
 '1Number of Rayleigh interactions in phantoms before reaching the detector',\
 '1Number of Rayleigh interactions in detectors before reaching the detector',\
 '1Scanner axial position', '1Scanner angular position',\
 '2Run ID', '2Event ID', '2Source ID',\
 '2Source Position X', '2Source Position Y',\
 '2Source Position Z', '2Time stamp', '2Deposited energy',\
 '2world referential Position X',\
 '2world referential Position Y',\
 '2world referential Position Z', '2Volume ID1(8-bytes, G4double)', '2Volume ID2(8-bytes, G4double)',\
 '2Volume ID3(8-bytes, G4double)', '2Volume ID4(4-bytes, G4int)', '2Volume ID5(4-bytes, G4int)', '2Volume ID6(4-bytes, G4int)', \
 '2Number of Compton interactions in phantoms before reaching the detector',\
 '2Number of Compton interactions in detectors before reaching the detector',\
 '2Number of Rayleigh interactions in phantoms before reaching the detector',\
 '2Number of Rayleigh interactions in detectors before reaching the detector',\
 '2Scanner axial position', '2Scanner angular position']

# %%
#dat_dir = input("Insert Directory : ")
dat_dir = "/home/yang/Desktop/OUTPUT/"
dat_file_list = glob.glob(dat_dir + '/*.dat')
dat_file_list.sort()
print(dat_file_list)

#os.mkdir(dat_dir + "/csv")

for i in range(len(dat_file_list)):
    #print(dat_file_list[i][:-3])
    dat_file_name = dat_file_list[i][26:]
    dat_file_name = dat_file_name[:-3]
    print(dat_file_name)
    shutil.copy(dat_file_list[i], dat_dir + dat_file_name +"csv")

csv_file_name = glob.glob(dat_dir + "*.csv")
csv_file_name.sort()
print(csv_file_name)
number_list = []
# Out:
# ['/home/yang/Desktop/OUTPUT/testCoincodences.dat']
# testCoincodences.
# ['/home/yang/Desktop/OUTPUT/testCoincodences.csv']

# %%
for i in range(len(dat_file_list)):
    print("--------------" + dat_file_list[i] + "----------------")
    f = codecs.open(csv_file_name[i])
    csv_data = csv.reader(f)
    f = open(csv_file_name[i][:26] + "csv/" + csv_file_name[i][26:],'w')
    for j in csv_data:
        j = " ".join(j)
        j = ' '.join(j.split())
        #print(j)
        j = list(j)
        #print(j)
        j.insert(0," ")
        index = 0
        l_num = 0
        enter = 0
        #print(j)
        
        for k in j:
            #print(k)
            if(k == " "):
                j[l_num] = "    \n'"+str(Column_list[index])+"':"
                index = index + 1
                l_num = l_num + 1
            elif(k == "\n"):
                index = 1
                enter = enter + 1
            else:
                l_num = l_num + 1
                
        #print(j)
        j = " ".join(j)
        j.lstrip()
        
        
        #j=list(j)
        #print(j)
        f.write(j + '\n' + "\n" + "\n")
        
        
        
         
print("Finish")
f.close()
# Out:
# --------------/home/yang/Desktop/OUTPUT/testCoincodences.dat----------------
# Finish

# %%
import os, glob, csv, codecs
import shutil
import re

Column_list =\
['1Run ID', '1Event ID', '1Source ID',\
 '1Source Position X', '1Source Position Y',\
 '1Source Position Z', '1Time stamp', '1Deposited energy',\
 '1world referential Position X',\
 '1world referential Position Y',\
 '1world referential Position Z', '1Volume ID1', '1Volume ID2',\
 '1Volume ID3', '1Volume ID4', '1Volume ID5', '1Volume ID6', \
 '1Number of Compton interactions in phantoms before reaching the detector',\
 '1Number of Compton interactions in detectors before reaching the detector',\
 '1Number of Rayleigh interactions in phantoms before reaching the detector',\
 '1Number of Rayleigh interactions in detectors before reaching the detector',\
 '1Scanner axial position', '1Scanner angular position',\
 '2Run ID', '2Event ID', '2Source ID',\
 '2Source Position X', '2Source Position Y',\
 '2Source Position Z', '2Time stamp', '2Deposited energy',\
 '2world referential Position X',\
 '2world referential Position Y',\
 '2world referential Position Z', '2Volume ID1', '2Volume ID2',\
 '2Volume ID3', '2Volume ID4', '2Volume ID5', '2Volume ID6', \
 '2Number of Compton interactions in phantoms before reaching the detector',\
 '2Number of Compton interactions in detectors before reaching the detector',\
 '2Number of Rayleigh interactions in phantoms before reaching the detector',\
 '2Number of Rayleigh interactions in detectors before reaching the detector',\
 '2Scanner axial position', '2Scanner angular position']


#dat_dir = input("Insert Directory : ")
dat_dir = "/home/yang/Desktop/OUTPUT/"
dat_file_list = glob.glob(dat_dir + '/*.dat')
dat_file_list.sort()
print(dat_file_list)

#os.mkdir(dat_dir + "/csv")

for i in range(len(dat_file_list)):
    #print(dat_file_list[i][:-3])
    dat_file_name = dat_file_list[i][26:]
    dat_file_name = dat_file_name[:-3]
    print(dat_file_name)
    shutil.copy(dat_file_list[i], dat_dir + dat_file_name +"csv")

csv_file_name = glob.glob(dat_dir + "*.csv")
csv_file_name.sort()
print(csv_file_name)
number_list = []


for i in range(len(dat_file_list)):
    print("--------------" + dat_file_list[i] + "----------------")
    f = codecs.open(csv_file_name[i])
    csv_data = csv.reader(f)
    f = open(csv_file_name[i][:26] + "csv/" + csv_file_name[i][26:],'w')
    for j in csv_data:
        j = " ".join(j)
        j = ' '.join(j.split())
        #print(j)
        j = list(j)
        #print(j)
        j.insert(0," ")
        index = 0
        l_num = 0
        enter = 0
        #print(j)
        
        for k in j:
            #print(k)
            if(k == " "):
                j[l_num] = "    \n'"+str(Column_list[index])+"':"
                index = index + 1
                l_num = l_num + 1
            elif(k == "\n"):
                index = 1
                enter = enter + 1
            else:
                l_num = l_num + 1
                
        #print(j)
        j = " ".join(j)
        j.lstrip()
        
        
        #j=list(j)
        print(j)
        f.write(j + '\n' + "\n" + "\n")
        
        
        
         
print("Finish")
f.close()
# Out:
# ['/home/yang/Desktop/OUTPUT/testCoincidence_scat.dat']
# testCoincidence_scat.
# ['/home/yang/Desktop/OUTPUT/testCoincidence_scat.csv']
# --------------/home/yang/Desktop/OUTPUT/testCoincidence_scat.dat----------------
#
# '1Run ID': 5 9
# '1Event ID': 5 2
# '1Source ID': 0
# '1Source Position X': 0 . 0 0 0 e + 0 0
# '1Source Position Y': 0 . 0 0 0 e + 0 0
# '1Source Position Z': 0 . 0 0 0 e + 0 0
# '1Time stamp': 5 . 9 4 2 3 0 4 7 7 3 9 5 4 2 4 5 4 3 3 7 4 2 4 7 e + 0 1
# '1Deposited energy': 5 . 7 4 3 e - 0 1
# '1world referential Position X': 3 . 5 7 7 e + 0 2
# '1world referential Position Y': 2 . 4 9 9 e + 0 2
# '1world referential Position Z': - 1 . 6 0 3 e - 0 3
# '1Volume ID1': 0
# '1Volume ID2': 1
# '1Volume ID3': 4
# '1Volume ID4': 0
# '1Volume ID5': 8
# '1Volume ID6': 0
# '1Number of Compton interactions in phantoms before reaching the detector': 0
# '1Number of Compton interactions in detectors before reaching the detector': 0
# ...

# %%
import os, glob, csv, codecs
import shutil
import re

#dat_dir = input("Insert Directory : ")
dat_dir = "/home/yang/Desktop/OUTPUT/"
dat_file_list = glob.glob(dat_dir + '/*.dat')
dat_file_list.sort()
print(dat_file_list)

#os.mkdir(dat_dir + "/csv")

for i in range(len(dat_file_list)):
    #print(dat_file_list[i][:-3])
    dat_file_name = dat_file_list[i][26:]
    dat_file_name = dat_file_name[:-3]
    print(dat_file_name)
    shutil.copy(dat_file_list[i], dat_dir + dat_file_name +"csv")

csv_file_name = glob.glob(dat_dir + "*.csv")
csv_file_name.sort()
print(csv_file_name)
number_list = []



for i in range(1):
    print("--------------" + dat_file_list[i] + "----------------")
    f = codecs.open(csv_file_name[i])
    csv_data = csv.reader(f)
    f = open(csv_file_name[i][:26] + "csv/" + csv_file_name[i][26:],'w')
    for j in csv_data:
        #print(j)
        j = " ".join(j)
        j = ' '.join(j.split())
        #print(j)
        j = list(j)
        j.insert(0," ")
        index = 1
        l_num = 0
        enter = 0
        #print(j)
        
        for k in j:
            #print(k)
            if(k == " "):
                j[l_num] = "    '"+str(index)+"':"
                index = index + 1
                l_num = l_num + 1
            elif(k == "\n"):
                index = 1
                enter = enter + 1
            else:
                l_num = l_num + 1
                
        
        j = "".join(j)
        j.lstrip()
        
        
        #j=list(j)
        #print(j)
        f.write(j + '\n')
        
        
        
         
print("Finish")
f.close()
